# %% [markdown]
# # Venues İstanbul
# ##  Problem Statement :
#
# İstanbul is most popular  city in Turkey and more than 15 million people choosing this beatifull city for their holiday every year from abroad. In this favourit holiday city, there are many many restaurants and cafes of different ambiance from many different food cultures. also there are many diffrent beachs resorts int this city.Traditional turkish cuisine, italian pizza restaurants, seafood restaurants, authentic middle east cafes, delicious kebab restaurants, turkish coffee, fast food, bistros, so many options for a tourist
#
# -  -

# %% [markdown]
# ##  Problem Discussion:
# There is not enough time for a tourist who has been come  on vacation for 10 days to get the experience up to the right place to choose the right restaurant for dinner.there is no time for a tourist to learn which restaurant is cooking better or which restaurant is cooking more delicious fish or which bar is making better music

# %% [markdown]
# ## Library Importing

# %%
# libraries for handle data and  data analsysis
import numpy as np 
import pandas as pd 
import json 

# handle requests libraries
import requests
from pandas.io.json import json_normalize

# Visiulation tools
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means 
from sklearn.cluster import KMeans



# map rendering library
# !conda install -c conda-forge folium=0.5.0 --yes ## install folium
import folium 

# beautiful soup
from urllib.request import urlopen
from bs4 import BeautifulSoup

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim

##


print('librariy importing is done !!')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# librariy importing is done !!

# %% [markdown]
# ## Fetching data from fourSquare
# We got ClientID and ClientSecret and we learned how we fetch data from fourSquare in earlier week

# %% [markdown]
# #### Getting Antalya geograpical coordinates with geopy

# %%
cntr = 'istanbul, Turkey'

geolocator = Nominatim()
location = geolocator.geocode(cntr)
latitude = location.latitude
longitude = location.longitude
print('Coordinates: {}, {}.'.format(latitude, longitude))
# Out:
# /home/savas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Coordinates: 41.0766019, 29.052495.

# %% [markdown]
# #### Setting FourSquare Request

# %%
## Your Api ClientID adn ClientSecret
CLIENT_ID = '5ONQYHNWGBZ4O0RJPBCSSWV4R2JRSNRKNUNNBLJIY4D42DEI' 
CLIENT_SECRET = 'BUKLQNAH1XVPOKXOVB0N0BZFUWYAHMY44CKPXQFZUL54I43V'

# Foursquare API version
VERSION = '20200404' 
radius  = 5000

print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)


LIMIT = 5000 


# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&limit={}&radius={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude,      
    LIMIT,
    radius)
print('Request Url:' + url)
# Out:
# CLIENT_ID: 5ONQYHNWGBZ4O0RJPBCSSWV4R2JRSNRKNUNNBLJIY4D42DEI
# CLIENT_SECRET:BUKLQNAH1XVPOKXOVB0N0BZFUWYAHMY44CKPXQFZUL54I43V
# Request Url:https://api.foursquare.com/v2/venues/explore?&client_id=5ONQYHNWGBZ4O0RJPBCSSWV4R2JRSNRKNUNNBLJIY4D42DEI&client_secret=BUKLQNAH1XVPOKXOVB0N0BZFUWYAHMY44CKPXQFZUL54I43V&v=20200404&ll=41.0766019,29.052495&limit=5000&radius=5000

# %% [markdown]
# #### Json data

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9ed2e1fb34b5001b107e48'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'With specials', 'key': 'specials'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 213,
#   'suggestedBounds': {'ne': {'lat': 41.121601945000045,
#     'lng': 29.112078617591987},
#    'sw': {'lat': 41.031601854999955, 'lng': 28.992911382408014}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50377a92e4b0fc42f6c6bb79',
#        'name': 'İoki',
#        'location': {'address': 'Kandilli Cad. No: 11/A',
#         'lat': 41.07389303418123,
#         'lng': 29.05780135224753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07389303418123,
#           'lng': 29.05780135224753}],
#         'distance': 537,
#         'postalCode': '34684',
#         'cc': 'TR',
#         'neighborhood': 'Kan',
#         'city': 'Üsküdar',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Kandilli Cad. No: 11/A',
#          '34684 Üsküdar',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50377a92e4b0fc42f6c6bb79-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7f764d564b8cfa42840565',
#        'name': 'Kandilli Sahili',
#        'location': {'address': 'Kandilli',
#         'crossStreet': 'Kandilli-Göksu Cd.',
#         'lat': 41.07437821689484,
#         'lng': 29.05956189718738,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07437821689484,
#           'lng': 29.05956189718738}],
#         'distance': 642,
#         'postalCode': '34684',
#         'cc': 'TR',
#         'city': 'Üsküdar',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Kandilli (Kandilli-Göksu Cd.)',
#          '34684 Üsküdar',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e2941735',
#          'name': 'Beach',
#          'pluralName': 'Beaches',
#          'shortName': 'Beach',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7f764d564b8cfa42840565-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1d862ac65b6cd0da9b2086',
#        'name': 'Adile Sultan Sarayı',
#        'location': {'address': 'Kandilli',
#         'lat': 41.0721587258395,
#         'lng': 29.058089230448864,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0721587258395,
#           'lng': 29.058089230448864}],
#         'distance': 681,
#         'postalCode': '34684',
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Kandilli', '34684 İstanbul', 'Türkiye']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1d862ac65b6cd0da9b2086-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d959f46942ba0934c733e8c',
#        'name': 'Mithat Alam Film Merkezi',
#        'location': {'address': 'Bogazici üniversitesi',
#         'crossStreet': 'Güney Kampüs',
#         'lat': 41.08295972573982,
#         'lng': 29.05028434229588,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08295972573982,
#           'lng': 29.05028434229588}],
#         'distance': 731,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Bogazici üniversitesi (Güney Kampüs)',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d959f46942ba0934c733e8c-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b811ccdf964a520379730e3',
#        'name': 'Bebek Parkı',
#        'location': {'address': 'Cevdetpaşa Cad. Bebek',
#         'lat': 41.07629409648552,
#         'lng': 29.044012383913195,
#         'distance': 712,
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Cevdetpaşa Cad. Bebek', 'Beşiktaş', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b811ccdf964a520379730e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4702daf964a5207b2a26e3',
#        'name': 'Starbucks',
#        'location': {'address': 'Bebek Mah. Cevdet Paşa Cad. No: 30',
#         'lat': 41.07760154364043,
#         'lng': 29.044208716538673,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07760154364043,
#           'lng': 29.044208716538673}],
#         'distance': 704,
#         'postalCode': '34342',
#         'cc': 'TR',
#         'neighborhood': 'Bebek',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Bebek Mah. Cevdet Paşa Cad. No: 30',
#          '34342 Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4702daf964a5207b2a26e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cef9c5c13aea1438322749f',
#        'name': 'Chilai',
#        'location': {'address': 'Bebek Mah. Cevdetpaşa Cad. No:60',
#         'lat': 41.07822704861733,
#         'lng': 29.04554387576872,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07822704861733,
#           'lng': 29.04554387576872}],
#         'distance': 610,
#         'postalCode': '34342',
#         'cc': 'TR',
#         'neighborhood': 'Bebek',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Bebek Mah. Cevdetpaşa Cad. No:60',
#          '34342 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cef9c5c13aea1438322749f-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cac6e0636fa6dcb1348de78',
#        'name': 'Aşiyan Müzesi',
#        'location': {'address': 'Aşiyan Yokuşu No:17 Bebek, Beşiktaş',
#         'lat': 41.08258167976911,
#         'lng': 29.05351159756526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08258167976911,
#           'lng': 29.05351159756526}],
#         'distance': 671,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Aşiyan Yokuşu No:17 Bebek, Beşiktaş',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cac6e0636fa6dcb1348de78-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '510e12d9e4b04d3f97533c27',
#        'name': 'Aşiyan Sahili',
#        'location': {'address': 'Aşiyan',
#         'lat': 41.08198963690145,
#         'lng': 29.055943657645678,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08198963690145,
#           'lng': 29.055943657645678}],
#         'distance': 665,
#         'cc': 'TR',
#         'neighborhood': 'Rumeli Hisarı',
#         'city': 'Sarıyer',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Aşiyan', 'Sarıyer, İstanbul', 'Türkiye']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-510e12d9e4b04d3f97533c27-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc8c7a4ab62d13ae60318d4',
#        'name': 'Bebek Sahili',
#        'location': {'address': 'Bebek',
#         'lat': 41.07615720905468,
#         'lng': 29.043108872829862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07615720905468,
#           'lng': 29.043108872829862}],
#         'distance': 789,
#         'cc': 'TR',
#         'neighborhood': 'Bebek',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Bebek', 'Beşiktaş', 'Türkiye']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc8c7a4ab62d13ae60318d4-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59dfb5c186bc495799852e2c',
#        'name': 'Etiler Gurme Kasabı & Izgara',
#        'location': {'address': 'Küçük Bebek Cd. 25/B',
#         'crossStreet': 'Küçük Bebek Cd.',
#         'lat': 41.07984728973875,
#         'lng': 29.044947494685623,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07984728973875,
#           'lng': 29.044947494685623}],
#         'distance': 729,
#         'postalCode': '34000',
#         'cc': 'TR',
#         'city': 'Bebek',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Küçük Bebek Cd. 25/B (Küçük Bebek Cd.)',
#          '34000 Bebek',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59dfb5c186bc495799852e2c-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8fd60d0b9e37046ca5625e',
#        'name': 'Manzara',
#        'location': {'address': 'Boğaziçi Üniversitesi Güney Kampüsü',
#         'lat': 41.0831835672842,
#         'lng': 29.053445000780016,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0831835672842,
#           'lng': 29.053445000780016}],
#         'distance': 736,
#         'cc': 'TR',
#         'city': 'Sarıyer',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Boğaziçi Üniversitesi Güney Kampüsü',
#          'Sarıyer',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8fd60d0b9e37046ca5625e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c28cbf63492a593efe3b728',
#        'name': 'Kennedy Lodge',
#        'location': {'address': 'Boğaziçi Üniversitesi, Güney Kampus',
#         'lat': 41.08370999786147,
#         'lng': 29.054448358815538,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08370999786147,
#           'lng': 29.054448358815538}],
#         'distance': 808,
#         'postalCode': '34342',
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Boğaziçi Üniversitesi, Güney Kampus',
#          '34342 Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c28cbf63492a593efe3b728-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c0559e498e1dba1db146fd',
#        'name': 'Granny’s Waffles',
#        'location': {'address': 'Cevdet Paşa Cd No:75A Bebek',
#         'crossStreet': 'Küçükbebek Caddesi',
#         'lat': 41.07877704378581,
#         'lng': 29.045751995304347,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07877704378581,
#           'lng': 29.045751995304347}],
#         'distance': 615,
#         'postalCode': '34342',
#         'cc': 'TR',
#         'neighborhood': 'Bebek, İstanbul',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Cevdet Paşa Cd No:75A Bebek (Küçükbebek Caddesi)',
#          '34342 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '89984037'}},
#       'referralId': 'e-0-52c0559e498e1dba1db146fd-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb5352b9a52ad1e3ed3ec34',
#        'name': 'Rumeli Hisarı',
#        'location': {'address': 'Rumeli Hisarı Mah. Yahya Kemal Cad.',
#         'lat': 41.08459157532555,
#         'lng': 29.056413173675537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08459157532555,
#           'lng': 29.056413173675537}],
#         'distance': 948,
#         'postalCode': '34470',
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Rumeli Hisarı Mah. Yahya Kemal Cad.',
#          '34470 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '50aaa49e4b90af0d42d5de11',
#          'name': 'Castle',
#          'pluralName': 'Castles',
#          'shortName': 'Castle',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '585194346'}},
#       'referralId': 'e-0-4eb5352b9a52ad1e3ed3ec34-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51475baee4b0910b705a62db',
#        'name': 'Cup of Joy',
#        'location': {'address': 'Cevdetpaşa Cad. No:53 Bebek',
#         'crossStreet': 'Yasemin Pasajı',
#         'lat': 41.07752601000696,
#         'lng': 29.043676244547818,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07752601000696,
#           'lng': 29.043676244547818}],
#         'distance': 747,
#         'postalCode': '34342',
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Cevdetpaşa Cad. No:53 Bebek (Yasemin Pasajı)',
#          '34342 Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52083764'}},
#       'referralId': 'e-0-51475baee4b0910b705a62db-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da8b0175da3ef8bf16460da',
#        'name': 'Petekler',
#        'location': {'address': 'Boğaziçi Üniversitesi Güney Kampüsü',
#         'lat': 41.083310508714504,
#         'lng': 29.048455934971606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.083310508714504,
#           'lng': 29.048455934971606}],
#         'distance': 820,
#         'postalCode': '34342',
#         'cc': 'TR',
#         'city': 'Sarıyer',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Boğaziçi Üniversitesi Güney Kampüsü',
#          '34342 Sarıyer',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da8b0175da3ef8bf16460da-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e5ba48e4b00f24b2617b97',
#        'name': 'Kortel Korusu',
#        'location': {'lat': 41.07311468663108,
#         'lng': 29.040017574437854,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07311468663108,
#           'lng': 29.040017574437854}],
#         'distance': 1116,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e5ba48e4b00f24b2617b97-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdb334dc79cc928f39b81e9',
#        'name': 'Akıntı Burnu Restaurant',
#        'location': {'address': 'Arnavutköy',
#         'lat': 41.06798824706154,
#         'lng': 29.04586301888372,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.06798824706154,
#           'lng': 29.04586301888372}],
#         'distance': 1108,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Arnavutköy', 'İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdb334dc79cc928f39b81e9-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d28bd55849f3704b2257741',
#        'name': 'Rago Balik',
#        'location': {'address': 'Arnavutköy',
#         'lat': 41.068703230386774,
#         'lng': 29.043679561700717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.068703230386774,
#           'lng': 29.043679561700717}],
#         'distance': 1149,
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Arnavutköy', 'İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'shortName': 'Cajun / Creole',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d28bd55849f3704b2257741-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb5af7d589f236afed3313d',
#        'name': 'Rumelihisarı Sahili',
#        'location': {'address': 'Rumelihisarı',
#         'crossStreet': 'Rumelihisarı - Bebek Arası',
#         'lat': 41.08776797686498,
#         'lng': 29.05684280163115,
#         'distance': 1295,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Rumelihisarı (Rumelihisarı - Bebek Arası)',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb5af7d589f236afed3313d-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7cdda57498a1cd6ff284fc',
#        'name': 'Küçüksu Kasrı',
#        'location': {'address': 'Göksu Mah. Anadolu Hisarı',
#         'lat': 41.07887052789256,
#         'lng': 29.065297332919055,
#         'distance': 1103,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Göksu Mah. Anadolu Hisarı',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7cdda57498a1cd6ff284fc-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf999aac6cca35d1c1c8132',
#        'name': 'Bodrum Mantı & Cafe',
#        'location': {'address': 'Arnavutköy Mah. Bebek Arnavutköy Cad. No:111',
#         'lat': 41.067606080928364,
#         'lng': 29.0453621750873,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.067606080928364,
#           'lng': 29.0453621750873}],
#         'distance': 1166,
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Arnavutköy Mah. Bebek Arnavutköy Cad. No:111',
#          'Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '5283c7b4e4b094cb91ec88d5',
#          'name': 'Manti Place',
#          'pluralName': 'Manti Places',
#          'shortName': 'Manti',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '140276785'}},
#       'referralId': 'e-0-4cf999aac6cca35d1c1c8132-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '549ec883498e71c901b76488',
#        'name': 'Chado Tea Shop',
#        'location': {'address': 'Francalacı Cad. No:9/A Arnavutköy',
#         'lat': 41.067583973124854,
#         'lng': 29.04342132113315,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.067583973124854,
#           'lng': 29.04342132113315}],
#         'distance': 1259,
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Francalacı Cad. No:9/A Arnavutköy',
#          'Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-549ec883498e71c901b76488-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4faad3fae4b0a76594b3972b',
#        'name': 'Sevda Tepesi',
#        'location': {'lat': 41.07373137031657,
#         'lng': 29.06556437029633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07373137031657,
#           'lng': 29.06556437029633}],
#         'distance': 1142,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['İstanbul', 'Türkiye']},
#        'categories': [{'id': '4eb1d4d54b900d56c88a45fc',
#          'name': 'Mountain',
#          'pluralName': 'Mountains',
#          'shortName': 'Mountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4faad3fae4b0a76594b3972b-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50f84fa1e4b093fc382edf9e',
#        'name': 'Etiler Manzara',
#        'location': {'address': 'Etiler',
#         'crossStreet': 'Nispetiye caddesi',
#         'lat': 41.084219791047644,
#         'lng': 29.042321904853384,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.084219791047644,
#           'lng': 29.042321904853384}],
#         'distance': 1203,
#         'cc': 'TR',
#         'country': 'Türkiye',
#         'formattedAddress': ['Etiler (Nispetiye caddesi)', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50f84fa1e4b093fc382edf9e-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0403cbf56c2d7f12a91d66',
#        'name': 'Arnavutköy Sahili',
#        'location': {'address': 'Arnavutköy',
#         'lat': 41.067374675187516,
#         'lng': 29.04201783346798,
#         'distance': 1352,
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Arnavutköy', 'Beşiktaş', 'Türkiye']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0403cbf56c2d7f12a91d66-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e326d0518a846d7ed075b74',
#        'name': 'Borusan Contemporary',
#        'location': {'address': 'Perili Kosk Baltalimani Hisar Caddesi No:5 Rumeli Hisari',
#         'lat': 41.0891045868547,
#         'lng': 29.056811588820437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0891045868547,
#           'lng': 29.056811588820437}],
#         'distance': 1438,
#         'postalCode': '34470',
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Perili Kosk Baltalimani Hisar Caddesi No:5 Rumeli Hisari',
#          '34470 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e326d0518a846d7ed075b74-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5992da31ca18ea65323cfa56',
#        'name': 'Zoom Rumelihisarı',
#        'location': {'address': 'Rumeli Hisarı Mah Yahya Kemal Cad. No:6/A SARIYER İSTANBUL',
#         'crossStreet': 'Yahya Kemal Caddesi',
#         'lat': 41.08807426567507,
#         'lng': 29.05654588181945,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08807426567507,
#           'lng': 29.05654588181945}],
#         'distance': 1321,
#         'postalCode': '34470',
#         'cc': 'TR',
#         'neighborhood': 'Rumeli Hisarı',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Rumeli Hisarı Mah Yahya Kemal Cad. No:6/A SARIYER İSTANBUL (Yahya Kemal Caddesi)',
#          '34470 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '452353091'}},
#       'referralId': 'e-0-5992da31ca18ea65323cfa56-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a21848cc3658812c1ca6fc4',
#        'name': 'Doorstep Coffee',
#        'location': {'address': 'Bebek Arnavutköy Cad. No: 93A Arnavutköy',
#         'crossStreet': 'Bebek Arnavutköy Caddesi',
#         'lat': 41.0675164686701,
#         'lng': 29.044012442708382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0675164686701,
#           'lng': 29.044012442708382}],
#         'distance': 1236,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Bebek Arnavutköy Cad. No: 93A Arnavutköy (Bebek Arnavutköy Caddesi)',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a21848cc3658812c1ca6fc4-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d6d1d6498e8fc69a1e591e',
#        'name': 'anadolu hisarı sahil',
#        'location': {'lat': 41.08254386258193,
#         'lng': 29.067058634653904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08254386258193,
#           'lng': 29.067058634653904}],
#         'distance': 1389,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52d6d1d6498e8fc69a1e591e-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c52f7547f6e20a1aae966ec',
#        'name': 'Arnavutköy Balıkçısı',
#        'location': {'address': 'Arnavutköy Mah. Bebek Arnavutköy Cad. No:4',
#         'lat': 41.06663996172256,
#         'lng': 29.04216572757555,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.06663996172256,
#           'lng': 29.04216572757555}],
#         'distance': 1407,
#         'postalCode': '34345',
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Arnavutköy Mah. Bebek Arnavutköy Cad. No:4',
#          '34345 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c52f7547f6e20a1aae966ec-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0c675be4b0065899eb0a8c',
#        'name': 'D-Gym Etiler',
#        'location': {'address': 'Etiler Mah. Selviler Sk. No: 16-17-28',
#         'lat': 41.07717573681804,
#         'lng': 29.033721506923545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07717573681804,
#           'lng': 29.033721506923545}],
#         'distance': 1576,
#         'postalCode': '34337',
#         'cc': 'TR',
#         'neighborhood': 'Etiler',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Etiler Mah. Selviler Sk. No: 16-17-28',
#          '34337 Etiler',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0c675be4b0065899eb0a8c-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55382bf6498e53f7c21f54c6',
#        'name': 'Muhit Tobacco & Coffee Shop',
#        'location': {'address': 'Boğaziçi Üniversitesi Rumeli Hisarüstü 5. Sok. No: 8/B',
#         'lat': 41.086460040251175,
#         'lng': 29.047817587857182,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.086460040251175,
#           'lng': 29.047817587857182}],
#         'distance': 1165,
#         'cc': 'TR',
#         'city': 'Sarıyer',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Boğaziçi Üniversitesi Rumeli Hisarüstü 5. Sok. No: 8/B',
#          'Sarıyer',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55382bf6498e53f7c21f54c6-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53511c15498ed5ccc1d7ba60',
#        'name': 'Happy Nest Istanbul',
#        'location': {'address': 'Kültür Mahallesi Onaran Sokak No: 2',
#         'crossStreet': 'Nispetiye Caddesi',
#         'lat': 41.07478520273672,
#         'lng': 29.033575143960263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07478520273672,
#           'lng': 29.033575143960263}],
#         'distance': 1600,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Kültür Mahallesi Onaran Sokak No: 2 (Nispetiye Caddesi)',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53511c15498ed5ccc1d7ba60-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eafee06d3e30d4483eb162d',
#        'name': 'LABOTTEGA',
#        'location': {'address': 'Baltalimanı Cad. No:17/1 Rumelihisarı',
#         'lat': 41.090056982175646,
#         'lng': 29.05651117511095,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.090056982175646,
#           'lng': 29.05651117511095}],
#         'distance': 1535,
#         'postalCode': '34470',
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Baltalimanı Cad. No:17/1 Rumelihisarı',
#          '34470 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '74569154'}},
#       'referralId': 'e-0-4eafee06d3e30d4483eb162d-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50422d5fe4b09fb67afe1cce',
#        'name': 'Time To Train Fitness Center',
#        'location': {'address': 'Rasathane Caddesi Boğaziçi Kandilli Evleri',
#         'crossStreet': 'Rasathane Caddesi',
#         'lat': 41.06691720133807,
#         'lng': 29.066570621979007,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.06691720133807,
#           'lng': 29.066570621979007}],
#         'distance': 1599,
#         'cc': 'TR',
#         'city': 'Üsküdar',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Rasathane Caddesi Boğaziçi Kandilli Evleri (Rasathane Caddesi)',
#          'Istanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50422d5fe4b09fb67afe1cce-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fcf83e8e4b0d44b55e64acc',
#        'name': 'Nusr-Et Steakhouse',
#        'location': {'address': 'Etiler Mah. Nisbetiye Cad. No:87',
#         'lat': 41.0805608468913,
#         'lng': 29.033428869124943,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0805608468913,
#           'lng': 29.033428869124943}],
#         'distance': 1659,
#         'postalCode': '34337',
#         'cc': 'TR',
#         'neighborhood': 'Etiler',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Etiler Mah. Nisbetiye Cad. No:87',
#          '34337 Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fcf83e8e4b0d44b55e64acc-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523d62af11d231c75dbafbc4',
#        'name': 'Marmara Üniversitesi Jimnastik Salonu',
#        'location': {'address': 'Cuma Yolu Cad.',
#         'lat': 41.08046659940623,
#         'lng': 29.072746773961157,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.08046659940623,
#           'lng': 29.072746773961157}],
#         'distance': 1753,
#         'cc': 'TR',
#         'city': 'Anadolu Hisarı',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Cuma Yolu Cad.', 'İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523d62af11d231c75dbafbc4-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56655e49498e2a648b4dadd3',
#        'name': 'Bi Nevi Deli',
#        'location': {'address': 'Bahtiyar Sokak No:4',
#         'crossStreet': 'Nispetiye',
#         'lat': 41.07973763575287,
#         'lng': 29.03323211325179,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07973763575287,
#           'lng': 29.03323211325179}],
#         'distance': 1653,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Bahtiyar Sokak No:4 (Nispetiye)',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '149313315'}},
#       'referralId': 'e-0-56655e49498e2a648b4dadd3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5773ba3c498e63c34d6aacd1',
#        'name': 'Wuufbox',
#        'location': {'address': 'Kurucesme',
#         'crossStreet': 'Kurucesme',
# ...
#          'name': 'Other Great Outdoors',
#          'pluralName': 'Other Great Outdoors',
#          'shortName': 'Other Outdoors',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fbbe081e4b0617d85e19d2f-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9edf6591af6ea83ec18ce8',
#        'name': 'Emirgan Camii',
#        'location': {'address': 'Emirgan Mah. Sakıp Sabancı Cad.',
#         'lat': 41.10481103046333,
#         'lng': 29.056182257557673,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.10481103046333,
#           'lng': 29.056182257557673}],
#         'distance': 3155,
#         'cc': 'TR',
#         'city': 'Sarıyer',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Emirgan Mah. Sakıp Sabancı Cad.',
#          'Sarıyer',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d138941735',
#          'name': 'Mosque',
#          'pluralName': 'Mosques',
#          'shortName': 'Mosque',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_mosque_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9edf6591af6ea83ec18ce8-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cde83ebc4f6a35d3046ca6c',
#        'name': 'Le Vent Kuaför',
#        'location': {'address': 'Karakol sok. No:12B 1.Levent',
#         'lat': 41.07534776127891,
#         'lng': 29.016570317972967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.07534776127891,
#           'lng': 29.016570317972967}],
#         'distance': 3017,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Karakol sok. No:12B 1.Levent',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d110951735',
#          'name': 'Salon / Barbershop',
#          'pluralName': 'Salons / Barbershops',
#          'shortName': 'Salon / Barbershop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cde83ebc4f6a35d3046ca6c-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a5df2fe4b05b355c5c1c92',
#        'name': 'Zorlu PSM',
#        'location': {'address': 'Zorlu Center',
#         'crossStreet': 'Levazım Mah. Koru Sok. No:2',
#         'lat': 41.06754706168132,
#         'lng': 29.016601956682685,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.06754706168132,
#           'lng': 29.016601956682685}],
#         'distance': 3176,
#         'postalCode': '34340',
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Zorlu Center (Levazım Mah. Koru Sok. No:2)',
#          '34340 Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85760582'}},
#       'referralId': 'e-0-50a5df2fe4b05b355c5c1c92-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c199b8498e3a62e897e19a',
#        'name': 'Çengelköy Waffle',
#        'location': {'address': 'Çengelköy Cad. No: 30',
#         'lat': 41.05015873428699,
#         'lng': 29.05339207414595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05015873428699,
#           'lng': 29.05339207414595}],
#         'distance': 2944,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Çengelköy Cad. No: 30', 'İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '90449257'}},
#       'referralId': 'e-0-53c199b8498e3a62e897e19a-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5957b64a840fc216ec1c83f1',
#        'name': 'Ragu Lokanta',
#        'location': {'address': 'Levazım Mah. Koru Sok.',
#         'lat': 41.06352581222088,
#         'lng': 29.01848523801252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.06352581222088,
#           'lng': 29.01848523801252}],
#         'distance': 3203,
#         'postalCode': '34340',
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Levazım Mah. Koru Sok.',
#          '34340 İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '430357121'}},
#       'referralId': 'e-0-5957b64a840fc216ec1c83f1-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bffb9b192a6c928b4f542e2',
#        'name': 'Sakıp Sabancı Müzesi',
#        'location': {'address': 'Sakıp Sabancı Cad. No:42 Emirgan',
#         'crossStreet': 'Atlı Köşk',
#         'lat': 41.10624907305421,
#         'lng': 29.055836399268383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.10624907305421,
#           'lng': 29.055836399268383}],
#         'distance': 3312,
#         'postalCode': '34467',
#         'cc': 'TR',
#         'city': 'Sarıyer',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Sakıp Sabancı Cad. No:42 Emirgan (Atlı Köşk)',
#          '34467 Sarıyer',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'events': {'count': 1,
#         'summary': 'Akış/Flux: Marina Abramović + MAI',
#         'items': [{'id': '5e3458bfeaef6d6d20ac2e33',
#           'name': 'Akış/Flux: Marina Abramović + MAI',
#           'categories': [],
#           'startAt': 1580489400,
#           'endAt': 1587919200,
#           'allDay': False,
#           'timeZone': 'Europe/Istanbul',
#           'text': '',
#           'images': [],
#           'stats': {'checkinsCount': 286, 'usersCount': 278}}]},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61257120'}},
#       'referralId': 'e-0-4bffb9b192a6c928b4f542e2-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e459c41d4c065cb6b943000',
#        'name': 'Çengelköy Sahili',
#        'location': {'address': 'Çengelköy',
#         'lat': 41.04979867171708,
#         'lng': 29.067149539998013,
#         'distance': 3227,
#         'cc': 'TR',
#         'city': 'Üsküdar',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Çengelköy', 'Üsküdar, İstanbul', 'Türkiye']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e459c41d4c065cb6b943000-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5730bf4d498e9d5244e895a9',
#        'name': 'Cup of Joy',
#        'location': {'address': 'Zorlu Center',
#         'crossStreet': 'Levazım Mah. Koru Sok. No:2',
#         'lat': 41.0654248833571,
#         'lng': 29.01801867314046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0654248833571,
#           'lng': 29.01801867314046}],
#         'distance': 3149,
#         'cc': 'TR',
#         'city': 'Beşiktaş',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Zorlu Center (Levazım Mah. Koru Sok. No:2)',
#          'Beşiktaş',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5730bf4d498e9d5244e895a9-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c14b748a1010f4740da4c18',
#        'name': 'Kanlıca Sahili',
#        'location': {'address': 'Kanlıca',
#         'lat': 41.09970618426415,
#         'lng': 29.07569440035958,
#         'distance': 3225,
#         'cc': 'TR',
#         'city': 'Beykoz',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Kanlıca', 'Beykoz', 'Türkiye']},
#        'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#          'name': 'Waterfront',
#          'pluralName': 'Waterfronts',
#          'shortName': 'Waterfront',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c14b748a1010f4740da4c18-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527e37d511d299685ade1145',
#        'name': 'Zorlu Center Park',
#        'location': {'address': 'Zorlu Center',
#         'crossStreet': 'Levazım Mah. Koru Sok. No:2',
#         'lat': 41.067335647580464,
#         'lng': 29.015273575006297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.067335647580464,
#           'lng': 29.015273575006297}],
#         'distance': 3289,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Zorlu Center (Levazım Mah. Koru Sok. No:2)',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-527e37d511d299685ade1145-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58cedc897b88a71aacfedfb4',
#        'name': 'Abant Kahvecisi',
#        'location': {'address': 'Çengelköy mahallesi , Çengelköy caddesi No:27/A Üsküdar',
#         'crossStreet': 'Çengelköy',
#         'lat': 41.05010049011769,
#         'lng': 29.053720764490766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05010049011769,
#           'lng': 29.053720764490766}],
#         'distance': 2951,
#         'postalCode': '34680',
#         'cc': 'TR',
#         'city': 'Kuleli',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Çengelköy mahallesi , Çengelköy caddesi No:27/A Üsküdar (Çengelköy)',
#          '34680 Kuleli',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58cedc897b88a71aacfedfb4-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5743104a498e6adb99b3ce0b',
#        'name': 'Maia Handmade Chocolate Atolye',
#        'location': {'lat': 41.05195440417318,
#         'lng': 29.07156650828918,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05195440417318,
#           'lng': 29.07156650828918}],
#         'distance': 3176,
#         'cc': 'TR',
#         'neighborhood': 'Güzeltepe',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['İstanbul', 'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5743104a498e6adb99b3ce0b-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '517a741fe4b0fb92e87c61aa',
#        'name': 'Sortie Niwa Bar',
#        'location': {'address': 'Muallim Naci Cad. No:54 Kurucesme',
#         'lat': 41.05246520714741,
#         'lng': 29.034149958957666,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05246520714741,
#           'lng': 29.034149958957666}],
#         'distance': 3096,
#         'cc': 'TR',
#         'city': 'İstanbul',
#         'state': 'İstanbul',
#         'country': 'Türkiye',
#         'formattedAddress': ['Muallim Naci Cad. No:54 Kurucesme',
#          'İstanbul',
#          'Türkiye']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-517a741fe4b0fb92e87c61aa-99'}]}]}}

# %% [markdown]
# #### How we can use this data ?
# Using Geolocator one can get the latitude and Longitude values of a particular place after fetching these values we can use Forsquare API calls on these places and gather the venues that are currently happening around.
# we can get venue categories from this data and  we can determine top venues for each category by like counts

# %% [markdown]
# ### 1- Creating dataframe

# %%
def get_category(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Scraping data from the Foursquare API

venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
filtered_columns = ['venue.name', 'venue.id', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filtering category
nearby_venues['venue.categories'] = nearby_venues.apply(get_category, axis=1)

nearby_venues
# Out:
# /home/savas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                         venue.name                  venue.id  \
# 0                             İoki  50377a92e4b0fc42f6c6bb79
# 1                  Kandilli Sahili  4d7f764d564b8cfa42840565
# 2              Adile Sultan Sarayı  4e1d862ac65b6cd0da9b2086
# 3         Mithat Alam Film Merkezi  4d959f46942ba0934c733e8c
# 4                      Bebek Parkı  4b811ccdf964a520379730e3
# ..                             ...                       ...
# 95                  Kanlıca Sahili  4c14b748a1010f4740da4c18
# 96               Zorlu Center Park  527e37d511d299685ade1145
# 97                 Abant Kahvecisi  58cedc897b88a71aacfedfb4
# 98  Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
# 99                 Sortie Niwa Bar  517a741fe4b0fb92e87c61aa
#
#     venue.categories  venue.location.lat  venue.location.lng
# 0   Sushi Restaurant           41.073893           29.057801
# 1              Beach           41.074378           29.059562
# 2      Historic Site           41.072159           29.058089
# 3      Movie Theater           41.082960           29.050284
# 4               Park           41.076294           29.044012
# ..               ...                 ...                 ...
# 95        Waterfront           41.099706           29.075694
# 96            Garden           41.067336           29.015274
# 97       Coffee Shop           41.050100           29.053721
# 98              Café           41.051954           29.071567
# 99         Nightclub           41.052465           29.034150
#
# [100 rows x 5 columns]

# %%
#fix the column names 

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#                               name                        id  \
# 0                             İoki  50377a92e4b0fc42f6c6bb79
# 1                  Kandilli Sahili  4d7f764d564b8cfa42840565
# 2              Adile Sultan Sarayı  4e1d862ac65b6cd0da9b2086
# 3         Mithat Alam Film Merkezi  4d959f46942ba0934c733e8c
# 4                      Bebek Parkı  4b811ccdf964a520379730e3
# ..                             ...                       ...
# 95                  Kanlıca Sahili  4c14b748a1010f4740da4c18
# 96               Zorlu Center Park  527e37d511d299685ade1145
# 97                 Abant Kahvecisi  58cedc897b88a71aacfedfb4
# 98  Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
# 99                 Sortie Niwa Bar  517a741fe4b0fb92e87c61aa
#
#           categories        lat        lng
# 0   Sushi Restaurant  41.073893  29.057801
# 1              Beach  41.074378  29.059562
# 2      Historic Site  41.072159  29.058089
# 3      Movie Theater  41.082960  29.050284
# 4               Park  41.076294  29.044012
# ..               ...        ...        ...
# 95        Waterfront  41.099706  29.075694
# 96            Garden  41.067336  29.015274
# 97       Coffee Shop  41.050100  29.053721
# 98              Café  41.051954  29.071567
# 99         Nightclub  41.052465  29.034150
#
# [100 rows x 5 columns]

# %%
cat_array = nearby_venues['categories'].unique()
cat_array
# Out:
# array(['Sushi Restaurant', 'Beach', 'Historic Site', 'Movie Theater',
#        'Park', 'Coffee Shop', 'Lounge', 'Art Museum', 'Waterfront',
#        'Steakhouse', 'Scenic Lookout', 'Restaurant', 'Dessert Shop',
#        'Castle', 'Seafood Restaurant', 'Cajun / Creole Restaurant',
#        'Manti Place', 'Tea Room', 'Mountain', 'Art Gallery', 'Café',
#        'Gym / Fitness Center', 'Bookstore', 'Furniture / Home Store',
#        'Gym', 'Vegetarian / Vegan Restaurant', 'Other Great Outdoors',
#        'Yoga Studio', 'Athletics & Sports', 'Kebab Restaurant',
#        'Flower Shop', 'Residential Building (Apartment / Condo)',
#        'Nightclub', 'Pastry Shop', 'Hotel', 'Lighthouse', 'Bakery',
#        'Music Venue', 'Sporting Goods Shop', 'Arts & Crafts Store',
#        'Pizza Place', 'Garden', 'Shop & Service', 'Concert Hall',
#        'Mosque', 'Salon / Barbershop', 'Performing Arts Venue', 'Diner'],
#       dtype=object)

# %% [markdown]
# we want to suggest to people restourant and cafe. Therefor we have to filter category array

# %%
def cat_filter(cat_arr, filter_words):
    new_array=[]
    for a in cat_arr:
        for b in filter_words:
            if b in a:
                new_array.append(a)
    return list(set(new_array))

# %%
#we want to suggest to people restourant or cafe. Therefor we have to filter category array


new_cat_array = cat_filter(cat_array, ['Restaurant', 'Café', 'Kebab', 'Diner', 'Pizza', 'Steakhouse'])
new_cat_array
# Out:
# ['Seafood Restaurant',
#  'Cajun / Creole Restaurant',
#  'Steakhouse',
#  'Sushi Restaurant',
#  'Restaurant',
#  'Café',
#  'Vegetarian / Vegan Restaurant',
#  'Kebab Restaurant',
#  'Diner',
#  'Pizza Place']

# %% [markdown]
# #### getting datas  restourants or caffes and likes

# %%
## getting restourants or caffes
venues_data = nearby_venues.loc[nearby_venues['categories'].isin(new_cat_array)]
venues_data
# Out:
#                                  name                        id  \
# 0                                İoki  50377a92e4b0fc42f6c6bb79
# 10       Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 12                      Kennedy Lodge  4c28cbf63492a593efe3b728
# 18            Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9
# 19                         Rago Balik  4d28bd55849f3704b2257741
# 28                  Zoom Rumelihisarı  5992da31ca18ea65323cfa56
# 31               Arnavutköy Balıkçısı  4c52f7547f6e20a1aae966ec
# 33        Muhit Tobacco & Coffee Shop  55382bf6498e53f7c21f54c6
# 37                 Nusr-Et Steakhouse  4fcf83e8e4b0d44b55e64acc
# 39                       Bi Nevi Deli  56655e49498e2a648b4dadd3
# 40                            Wuufbox  5773ba3c498e63c34d6aacd1
# 44           Byulus Steakhouse&Burger  59bd56c92079551e2b7eb007
# 46                      Uskumru Balık  4b6dbc38f964a520da8a2ce3
# 49                 Sunset Grill & Bar  4b66b8dff964a520a7282be3
# 51                Lacivert Restaurant  4c753eb13adda14327b606af
# 52                        Tike Etiler  5b18201ff62f2b002cf2afb7
# 55                               İoki  5550cd42498e75da5efa6f0f
# 62                      Inari Omakase  5176610e498efe5001ae652e
# 68              Mavi Balık Restaurant  4c07fd3cffb8c9b6b48a6761
# 75         Imperia Pizza & Sandwiches  584298a7dfa6ff53e05ce9c8
# 77                  Olivia's Pizzeria  4bd710da29eb9c74ab1796e1
# 79  Suma Cafe Restaurant/Göksu Evleri  57a1cc8b498e898a681abefa
# 84                         Nilda Kafe  5711375c498eaa8b74bbef2c
# 91                       Ragu Lokanta  5957b64a840fc216ec1c83f1
# 98     Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
#
#                        categories        lat        lng
# 0                Sushi Restaurant  41.073893  29.057801
# 10                     Steakhouse  41.079847  29.044947
# 12                     Restaurant  41.083710  29.054448
# 18             Seafood Restaurant  41.067988  29.045863
# 19      Cajun / Creole Restaurant  41.068703  29.043680
# 28                           Café  41.088074  29.056546
# 31             Seafood Restaurant  41.066640  29.042166
# 33                           Café  41.086460  29.047818
# 37                     Steakhouse  41.080561  29.033429
# 39  Vegetarian / Vegan Restaurant  41.079738  29.033232
# 40                           Café  41.065588  29.041184
# 44                     Steakhouse  41.071683  29.028886
# 46             Seafood Restaurant  41.091037  29.066344
# 49                     Restaurant  41.064121  29.033130
# 51             Seafood Restaurant  41.091380  29.066438
# 52               Kebab Restaurant  41.086600  29.032461
# 55               Sushi Restaurant  41.074872  29.027626
# 62               Sushi Restaurant  41.059915  29.036412
# 68             Seafood Restaurant  41.058035  29.035684
# 75                           Café  41.093625  29.032860
# 77                    Pizza Place  41.073497  29.020494
# 79                     Restaurant  41.082145  29.086457
# 84                           Café  41.050679  29.053424
# 91                          Diner  41.063526  29.018485
# 98                           Café  41.051954  29.071567

# %%
#getting id list

id_list = venues_data['id'].tolist()
id_list
# Out:
# ['50377a92e4b0fc42f6c6bb79',
#  '59dfb5c186bc495799852e2c',
#  '4c28cbf63492a593efe3b728',
#  '4bdb334dc79cc928f39b81e9',
#  '4d28bd55849f3704b2257741',
#  '5992da31ca18ea65323cfa56',
#  '4c52f7547f6e20a1aae966ec',
#  '55382bf6498e53f7c21f54c6',
#  '4fcf83e8e4b0d44b55e64acc',
#  '56655e49498e2a648b4dadd3',
#  '5773ba3c498e63c34d6aacd1',
#  '59bd56c92079551e2b7eb007',
#  '4b6dbc38f964a520da8a2ce3',
#  '4b66b8dff964a520a7282be3',
#  '4c753eb13adda14327b606af',
#  '5b18201ff62f2b002cf2afb7',
#  '5550cd42498e75da5efa6f0f',
#  '5176610e498efe5001ae652e',
#  '4c07fd3cffb8c9b6b48a6761',
#  '584298a7dfa6ff53e05ce9c8',
#  '4bd710da29eb9c74ab1796e1',
#  '57a1cc8b498e898a681abefa',
#  '5711375c498eaa8b74bbef2c',
#  '5957b64a840fc216ec1c83f1',
#  '5743104a498e6adb99b3ce0b']

# %%
## getting like counts


url_list = []
like_list = []
json_list = []

for i in id_list:
    venue_url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(i, CLIENT_ID, CLIENT_SECRET, VERSION)
    url_list.append(venue_url)
for link in url_list:
    result = requests.get(link).json()
    likes = result['response']['likes']['count']
    like_list.append(likes)
print(like_list)
# Out:
# [822, 32, 327, 395, 100, 380, 1671, 24, 9130, 230, 54, 53, 1332, 3200, 2918, 29, 430, 575, 710, 47, 504, 19, 321, 45, 61]

# %%
## adding like numbers to data frame


venues_data['Likes'] = like_list
venues_data
# Out:
# /home/savas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                  name                        id  \
# 0                                İoki  50377a92e4b0fc42f6c6bb79
# 10       Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 12                      Kennedy Lodge  4c28cbf63492a593efe3b728
# 18            Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9
# 19                         Rago Balik  4d28bd55849f3704b2257741
# 28                  Zoom Rumelihisarı  5992da31ca18ea65323cfa56
# 31               Arnavutköy Balıkçısı  4c52f7547f6e20a1aae966ec
# 33        Muhit Tobacco & Coffee Shop  55382bf6498e53f7c21f54c6
# 37                 Nusr-Et Steakhouse  4fcf83e8e4b0d44b55e64acc
# 39                       Bi Nevi Deli  56655e49498e2a648b4dadd3
# 40                            Wuufbox  5773ba3c498e63c34d6aacd1
# 44           Byulus Steakhouse&Burger  59bd56c92079551e2b7eb007
# 46                      Uskumru Balık  4b6dbc38f964a520da8a2ce3
# 49                 Sunset Grill & Bar  4b66b8dff964a520a7282be3
# 51                Lacivert Restaurant  4c753eb13adda14327b606af
# 52                        Tike Etiler  5b18201ff62f2b002cf2afb7
# 55                               İoki  5550cd42498e75da5efa6f0f
# 62                      Inari Omakase  5176610e498efe5001ae652e
# 68              Mavi Balık Restaurant  4c07fd3cffb8c9b6b48a6761
# 75         Imperia Pizza & Sandwiches  584298a7dfa6ff53e05ce9c8
# 77                  Olivia's Pizzeria  4bd710da29eb9c74ab1796e1
# 79  Suma Cafe Restaurant/Göksu Evleri  57a1cc8b498e898a681abefa
# 84                         Nilda Kafe  5711375c498eaa8b74bbef2c
# 91                       Ragu Lokanta  5957b64a840fc216ec1c83f1
# 98     Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
#
#                        categories        lat        lng  Likes
# 0                Sushi Restaurant  41.073893  29.057801    822
# 10                     Steakhouse  41.079847  29.044947     32
# 12                     Restaurant  41.083710  29.054448    327
# 18             Seafood Restaurant  41.067988  29.045863    395
# 19      Cajun / Creole Restaurant  41.068703  29.043680    100
# 28                           Café  41.088074  29.056546    380
# 31             Seafood Restaurant  41.066640  29.042166   1671
# 33                           Café  41.086460  29.047818     24
# 37                     Steakhouse  41.080561  29.033429   9130
# 39  Vegetarian / Vegan Restaurant  41.079738  29.033232    230
# 40                           Café  41.065588  29.041184     54
# 44                     Steakhouse  41.071683  29.028886     53
# 46             Seafood Restaurant  41.091037  29.066344   1332
# 49                     Restaurant  41.064121  29.033130   3200
# 51             Seafood Restaurant  41.091380  29.066438   2918
# 52               Kebab Restaurant  41.086600  29.032461     29
# 55               Sushi Restaurant  41.074872  29.027626    430
# 62               Sushi Restaurant  41.059915  29.036412    575
# 68             Seafood Restaurant  41.058035  29.035684    710
# 75                           Café  41.093625  29.032860     47
# 77                    Pizza Place  41.073497  29.020494    504
# 79                     Restaurant  41.082145  29.086457     19
# 84                           Café  41.050679  29.053424    321
# 91                          Diner  41.063526  29.018485     45
# 98                           Café  41.051954  29.071567     61

# %%
venues_data['Likes'].hist()
plt.show()

# %%
venues_data.sort_values(by=['Likes'],ascending=False)
# Out:
#                                  name                        id  \
# 37                 Nusr-Et Steakhouse  4fcf83e8e4b0d44b55e64acc
# 49                 Sunset Grill & Bar  4b66b8dff964a520a7282be3
# 51                Lacivert Restaurant  4c753eb13adda14327b606af
# 31               Arnavutköy Balıkçısı  4c52f7547f6e20a1aae966ec
# 46                      Uskumru Balık  4b6dbc38f964a520da8a2ce3
# 0                                İoki  50377a92e4b0fc42f6c6bb79
# 68              Mavi Balık Restaurant  4c07fd3cffb8c9b6b48a6761
# 62                      Inari Omakase  5176610e498efe5001ae652e
# 77                  Olivia's Pizzeria  4bd710da29eb9c74ab1796e1
# 55                               İoki  5550cd42498e75da5efa6f0f
# 18            Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9
# 28                  Zoom Rumelihisarı  5992da31ca18ea65323cfa56
# 12                      Kennedy Lodge  4c28cbf63492a593efe3b728
# 84                         Nilda Kafe  5711375c498eaa8b74bbef2c
# 39                       Bi Nevi Deli  56655e49498e2a648b4dadd3
# 19                         Rago Balik  4d28bd55849f3704b2257741
# 98     Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
# 40                            Wuufbox  5773ba3c498e63c34d6aacd1
# 44           Byulus Steakhouse&Burger  59bd56c92079551e2b7eb007
# 75         Imperia Pizza & Sandwiches  584298a7dfa6ff53e05ce9c8
# 91                       Ragu Lokanta  5957b64a840fc216ec1c83f1
# 10       Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 52                        Tike Etiler  5b18201ff62f2b002cf2afb7
# 33        Muhit Tobacco & Coffee Shop  55382bf6498e53f7c21f54c6
# 79  Suma Cafe Restaurant/Göksu Evleri  57a1cc8b498e898a681abefa
#
#                        categories        lat        lng  Likes
# 37                     Steakhouse  41.080561  29.033429   9130
# 49                     Restaurant  41.064121  29.033130   3200
# 51             Seafood Restaurant  41.091380  29.066438   2918
# 31             Seafood Restaurant  41.066640  29.042166   1671
# 46             Seafood Restaurant  41.091037  29.066344   1332
# 0                Sushi Restaurant  41.073893  29.057801    822
# 68             Seafood Restaurant  41.058035  29.035684    710
# 62               Sushi Restaurant  41.059915  29.036412    575
# 77                    Pizza Place  41.073497  29.020494    504
# 55               Sushi Restaurant  41.074872  29.027626    430
# 18             Seafood Restaurant  41.067988  29.045863    395
# 28                           Café  41.088074  29.056546    380
# 12                     Restaurant  41.083710  29.054448    327
# 84                           Café  41.050679  29.053424    321
# 39  Vegetarian / Vegan Restaurant  41.079738  29.033232    230
# 19      Cajun / Creole Restaurant  41.068703  29.043680    100
# 98                           Café  41.051954  29.071567     61
# 40                           Café  41.065588  29.041184     54
# 44                     Steakhouse  41.071683  29.028886     53
# 75                           Café  41.093625  29.032860     47
# 91                          Diner  41.063526  29.018485     45
# 10                     Steakhouse  41.079847  29.044947     32
# 52               Kebab Restaurant  41.086600  29.032461     29
# 33                           Café  41.086460  29.047818     24
# 79                     Restaurant  41.082145  29.086457     19

# %%
# now let's bin total likes

max_l = venues_data['Likes'].max()
min_l = venues_data['Likes'].min()
median_l = venues_data['Likes'].median()
mean_l = venues_data['Likes'].mean()


##print ( 'mean={}, median={}, max value = {}, min value={}'.format(mean_l, median_l, max_l, min_l)  )
print('mean = '+str(mean_l))
print('median = '+str(median_l))
print('max = '+str(max_l))
print('min = '+str(min_l))
# Out:
# mean = 936.36
# median = 327.0
# max = 9130
# min = 19

# %% [markdown]
# #### Rating the Venues Based on Total likes

# %%
# what are the bins we want to use?
q_1 = np.percentile(venues_data['Likes'], 25)
q_2 = np.percentile(venues_data['Likes'], 50)
q_3 = np.percentile(venues_data['Likes'], 75)
print(q_1)
print(q_2)
print(q_3)
# Out:
# 53.0
# 327.0
# 710.0

# %%
# now we have our bin values so let's set them to the appropriate values

# poor, below avg, abv avg, great

# %%
# let's set up a function that will re-categorize our restaurants based on likes

def conditions(s):
    if s['Likes']<=q_1:
        return 'poor'
    if s['Likes']<=q_2:
        return 'below avg'
    if s['Likes']<=q_3:
        return 'avg avg'
    if s['Likes']>q_3:
        return 'great'

venues_data['Like Cat']=venues_data.apply(conditions, axis=1)
venues_data
# Out:
# /home/savas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                                  name                        id  \
# 0                                İoki  50377a92e4b0fc42f6c6bb79
# 10       Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 12                      Kennedy Lodge  4c28cbf63492a593efe3b728
# 18            Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9
# 19                         Rago Balik  4d28bd55849f3704b2257741
# 28                  Zoom Rumelihisarı  5992da31ca18ea65323cfa56
# 31               Arnavutköy Balıkçısı  4c52f7547f6e20a1aae966ec
# 33        Muhit Tobacco & Coffee Shop  55382bf6498e53f7c21f54c6
# 37                 Nusr-Et Steakhouse  4fcf83e8e4b0d44b55e64acc
# 39                       Bi Nevi Deli  56655e49498e2a648b4dadd3
# 40                            Wuufbox  5773ba3c498e63c34d6aacd1
# 44           Byulus Steakhouse&Burger  59bd56c92079551e2b7eb007
# 46                      Uskumru Balık  4b6dbc38f964a520da8a2ce3
# 49                 Sunset Grill & Bar  4b66b8dff964a520a7282be3
# 51                Lacivert Restaurant  4c753eb13adda14327b606af
# 52                        Tike Etiler  5b18201ff62f2b002cf2afb7
# 55                               İoki  5550cd42498e75da5efa6f0f
# 62                      Inari Omakase  5176610e498efe5001ae652e
# 68              Mavi Balık Restaurant  4c07fd3cffb8c9b6b48a6761
# 75         Imperia Pizza & Sandwiches  584298a7dfa6ff53e05ce9c8
# 77                  Olivia's Pizzeria  4bd710da29eb9c74ab1796e1
# 79  Suma Cafe Restaurant/Göksu Evleri  57a1cc8b498e898a681abefa
# 84                         Nilda Kafe  5711375c498eaa8b74bbef2c
# 91                       Ragu Lokanta  5957b64a840fc216ec1c83f1
# 98     Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
#
#                        categories        lat        lng  Likes   Like Cat
# 0                Sushi Restaurant  41.073893  29.057801    822      great
# 10                     Steakhouse  41.079847  29.044947     32       poor
# 12                     Restaurant  41.083710  29.054448    327  below avg
# 18             Seafood Restaurant  41.067988  29.045863    395    avg avg
# 19      Cajun / Creole Restaurant  41.068703  29.043680    100  below avg
# 28                           Café  41.088074  29.056546    380    avg avg
# 31             Seafood Restaurant  41.066640  29.042166   1671      great
# 33                           Café  41.086460  29.047818     24       poor
# 37                     Steakhouse  41.080561  29.033429   9130      great
# 39  Vegetarian / Vegan Restaurant  41.079738  29.033232    230  below avg
# 40                           Café  41.065588  29.041184     54  below avg
# 44                     Steakhouse  41.071683  29.028886     53       poor
# 46             Seafood Restaurant  41.091037  29.066344   1332      great
# 49                     Restaurant  41.064121  29.033130   3200      great
# 51             Seafood Restaurant  41.091380  29.066438   2918      great
# 52               Kebab Restaurant  41.086600  29.032461     29       poor
# 55               Sushi Restaurant  41.074872  29.027626    430    avg avg
# 62               Sushi Restaurant  41.059915  29.036412    575    avg avg
# 68             Seafood Restaurant  41.058035  29.035684    710    avg avg
# 75                           Café  41.093625  29.032860     47       poor
# 77                    Pizza Place  41.073497  29.020494    504    avg avg
# 79                     Restaurant  41.082145  29.086457     19       poor
# 84                           Café  41.050679  29.053424    321  below avg
# 91                          Diner  41.063526  29.018485     45       poor
# 98                           Café  41.051954  29.071567     61  below avg

# %%
import matplotlib.pyplot as plt
N = len(venues_data)
x = venues_data['Like Cat']
y = venues_data['Likes'] #np.random.rand(N)

colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### K-Means Clustering
# #### set type

# %%
Cafe = ['Hotel', 'Bagel Shop', 'Bakery', 'Coffee Shop', 'Café', 'Sandwich Place', 'Bubble Tea Shop', 'Wine Shop', 'Plaza',  'Breakfast Spot', 'Salad Place']
restaurant = ['Falafel Restaurant','Restaurant', 'Italian Restaurant','Seafood Restaurant', 'Steakhouse','Korean Restaurant', 'Cuban Restaurant', 'Fast Food Restaurant', 'Japanese Restaurant',
                         'Sushi Restaurant', 'Indian Restaurant', 'Japanese Restaurant', 'Greek Restaurant', 'French Restaurant', 
                          'Japanese Curry Restaurant', 'Vegetarian / Vegan Restaurant','Asian Restaurant']

italian= ['Italian Restaurant', 'Cajun / Creole Restaurant', 'Pizza Place']

def type_set(s):
    if s['categories'] in Cafe:
        return 'Cafe'
    if s['categories'] in restaurant:
        return 'restaurant'
    if s['categories'] in italian:
        return 'Italian'
venues_data['type']=venues_data.apply(type_set, axis=1)
venues_data
# Out:
# /home/savas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                                  name                        id  \
# 0                                İoki  50377a92e4b0fc42f6c6bb79
# 10       Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 12                      Kennedy Lodge  4c28cbf63492a593efe3b728
# 18            Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9
# 19                         Rago Balik  4d28bd55849f3704b2257741
# 28                  Zoom Rumelihisarı  5992da31ca18ea65323cfa56
# 31               Arnavutköy Balıkçısı  4c52f7547f6e20a1aae966ec
# 33        Muhit Tobacco & Coffee Shop  55382bf6498e53f7c21f54c6
# 37                 Nusr-Et Steakhouse  4fcf83e8e4b0d44b55e64acc
# 39                       Bi Nevi Deli  56655e49498e2a648b4dadd3
# 40                            Wuufbox  5773ba3c498e63c34d6aacd1
# 44           Byulus Steakhouse&Burger  59bd56c92079551e2b7eb007
# 46                      Uskumru Balık  4b6dbc38f964a520da8a2ce3
# 49                 Sunset Grill & Bar  4b66b8dff964a520a7282be3
# 51                Lacivert Restaurant  4c753eb13adda14327b606af
# 52                        Tike Etiler  5b18201ff62f2b002cf2afb7
# 55                               İoki  5550cd42498e75da5efa6f0f
# 62                      Inari Omakase  5176610e498efe5001ae652e
# 68              Mavi Balık Restaurant  4c07fd3cffb8c9b6b48a6761
# 75         Imperia Pizza & Sandwiches  584298a7dfa6ff53e05ce9c8
# 77                  Olivia's Pizzeria  4bd710da29eb9c74ab1796e1
# 79  Suma Cafe Restaurant/Göksu Evleri  57a1cc8b498e898a681abefa
# 84                         Nilda Kafe  5711375c498eaa8b74bbef2c
# 91                       Ragu Lokanta  5957b64a840fc216ec1c83f1
# 98     Maia Handmade Chocolate Atolye  5743104a498e6adb99b3ce0b
#
#                        categories        lat        lng  Likes   Like Cat  \
# 0                Sushi Restaurant  41.073893  29.057801    822      great
# 10                     Steakhouse  41.079847  29.044947     32       poor
# 12                     Restaurant  41.083710  29.054448    327  below avg
# 18             Seafood Restaurant  41.067988  29.045863    395    avg avg
# 19      Cajun / Creole Restaurant  41.068703  29.043680    100  below avg
# 28                           Café  41.088074  29.056546    380    avg avg
# 31             Seafood Restaurant  41.066640  29.042166   1671      great
# 33                           Café  41.086460  29.047818     24       poor
# 37                     Steakhouse  41.080561  29.033429   9130      great
# 39  Vegetarian / Vegan Restaurant  41.079738  29.033232    230  below avg
# 40                           Café  41.065588  29.041184     54  below avg
# 44                     Steakhouse  41.071683  29.028886     53       poor
# 46             Seafood Restaurant  41.091037  29.066344   1332      great
# 49                     Restaurant  41.064121  29.033130   3200      great
# 51             Seafood Restaurant  41.091380  29.066438   2918      great
# 52               Kebab Restaurant  41.086600  29.032461     29       poor
# 55               Sushi Restaurant  41.074872  29.027626    430    avg avg
# 62               Sushi Restaurant  41.059915  29.036412    575    avg avg
# 68             Seafood Restaurant  41.058035  29.035684    710    avg avg
# 75                           Café  41.093625  29.032860     47       poor
# 77                    Pizza Place  41.073497  29.020494    504    avg avg
# 79                     Restaurant  41.082145  29.086457     19       poor
# 84                           Café  41.050679  29.053424    321  below avg
# 91                          Diner  41.063526  29.018485     45       poor
# 98                           Café  41.051954  29.071567     61  below avg
#
#           type
# 0   restaurant
# 10  restaurant
# 12  restaurant
# 18  restaurant
# 19     Italian
# 28        Cafe
# 31  restaurant
# 33        Cafe
# 37  restaurant
# 39  restaurant
# 40        Cafe
# 44  restaurant
# 46  restaurant
# 49  restaurant
# 51  restaurant
# 52        None
# 55  restaurant
# 62  restaurant
# 68  restaurant
# 75        Cafe
# 77     Italian
# 79  restaurant
# 84        Cafe
# 91        None
# 98        Cafe

# %% [markdown]
# ### One hat encoding

# %%
# one hot encoding
venues_data_onehot = pd.get_dummies(venues_data[['type', 'Like Cat']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
venues_data_onehot['Name'] = venues_data['name'] 

# move neighborhood column to the first column
fixed_columns = [venues_data_onehot.columns[-1]] + list(venues_data_onehot.columns[:-1])
venues_data_onehot = venues_data_onehot[fixed_columns]

venues_data_onehot.head()
# Out:
#                             Name  Cafe  Italian  restaurant  avg avg  \
# 0                           İoki     0        0           1        0
# 10  Etiler Gurme Kasabı & Izgara     0        0           1        0
# 12                 Kennedy Lodge     0        0           1        0
# 18       Akıntı Burnu Restaurant     0        0           1        1
# 19                    Rago Balik     0        1           0        0
#
#     below avg  great  poor
# 0           0      1     0
# 10          0      0     1
# 12          1      0     0
# 18          0      0     0
# 19          1      0     0

# %%
cluster_df = venues_data_onehot.drop('Name', axis=1)

k_clusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=k_clusters, random_state=0).fit(cluster_df)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 1, 0, 2, 0, 2, 3, 1, 3, 0], dtype=int32)

# %%
venues_data['label'] = kmeans.labels_
venues_data.head()
# Out:
# /home/savas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                             name                        id  \
# 0                           İoki  50377a92e4b0fc42f6c6bb79
# 10  Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 12                 Kennedy Lodge  4c28cbf63492a593efe3b728
# 18       Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9
# 19                    Rago Balik  4d28bd55849f3704b2257741
#
#                    categories        lat        lng  Likes   Like Cat  \
# 0            Sushi Restaurant  41.073893  29.057801    822      great
# 10                 Steakhouse  41.079847  29.044947     32       poor
# 12                 Restaurant  41.083710  29.054448    327  below avg
# 18         Seafood Restaurant  41.067988  29.045863    395    avg avg
# 19  Cajun / Creole Restaurant  41.068703  29.043680    100  below avg
#
#           type  label
# 0   restaurant      3
# 10  restaurant      1
# 12  restaurant      0
# 18  restaurant      2
# 19     Italian      0

# %% [markdown]
# ### Creating map

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(k_clusters)
ys = [i+x+(i*x)**2 for i in range(k_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys))) ##np.random.rand(N)
rainbow =[] ## [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(venues_data['lat'], venues_data['lng'], venues_data['name'], venues_data['label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color='#3186cc',
        fill=True,
        fill_color='#3c763d',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Results
#
# ###  Clustering

# %% [markdown]
# ### shows the rating for poor quality of venues

# %%
venues_data.loc[venues_data['label']==0]
# Out:
#              name                        id                     categories  \
# 12  Kennedy Lodge  4c28cbf63492a593efe3b728                     Restaurant
# 19     Rago Balik  4d28bd55849f3704b2257741      Cajun / Creole Restaurant
# 39   Bi Nevi Deli  56655e49498e2a648b4dadd3  Vegetarian / Vegan Restaurant
#
#           lat        lng  Likes   Like Cat        type  label
# 12  41.083710  29.054448    327  below avg  restaurant      0
# 19  41.068703  29.043680    100  below avg     Italian      0
# 39  41.079738  29.033232    230  below avg  restaurant      0

# %% [markdown]
# ###  shows rating for Great quality of veues

# %%
venues_data.loc[venues_data['label']==1]
# Out:
#                                  name                        id  \
# 10       Etiler Gurme Kasabı & Izgara  59dfb5c186bc495799852e2c
# 33        Muhit Tobacco & Coffee Shop  55382bf6498e53f7c21f54c6
# 44           Byulus Steakhouse&Burger  59bd56c92079551e2b7eb007
# 52                        Tike Etiler  5b18201ff62f2b002cf2afb7
# 75         Imperia Pizza & Sandwiches  584298a7dfa6ff53e05ce9c8
# 79  Suma Cafe Restaurant/Göksu Evleri  57a1cc8b498e898a681abefa
# 91                       Ragu Lokanta  5957b64a840fc216ec1c83f1
#
#           categories        lat        lng  Likes Like Cat        type  label
# 10        Steakhouse  41.079847  29.044947     32     poor  restaurant      1
# 33              Café  41.086460  29.047818     24     poor        Cafe      1
# 44        Steakhouse  41.071683  29.028886     53     poor  restaurant      1
# 52  Kebab Restaurant  41.086600  29.032461     29     poor        None      1
# 75              Café  41.093625  29.032860     47     poor        Cafe      1
# 79        Restaurant  41.082145  29.086457     19     poor  restaurant      1
# 91             Diner  41.063526  29.018485     45     poor        None      1

# %% [markdown]
# ### shows avg rated category venues

# %%
venues_data.loc[venues_data['label']==2]
# Out:
#                        name                        id          categories  \
# 18  Akıntı Burnu Restaurant  4bdb334dc79cc928f39b81e9  Seafood Restaurant
# 28        Zoom Rumelihisarı  5992da31ca18ea65323cfa56                Café
# 55                     İoki  5550cd42498e75da5efa6f0f    Sushi Restaurant
# 62            Inari Omakase  5176610e498efe5001ae652e    Sushi Restaurant
# 68    Mavi Balık Restaurant  4c07fd3cffb8c9b6b48a6761  Seafood Restaurant
# 77        Olivia's Pizzeria  4bd710da29eb9c74ab1796e1         Pizza Place
#
#           lat        lng  Likes Like Cat        type  label
# 18  41.067988  29.045863    395  avg avg  restaurant      2
# 28  41.088074  29.056546    380  avg avg        Cafe      2
# 55  41.074872  29.027626    430  avg avg  restaurant      2
# 62  41.059915  29.036412    575  avg avg  restaurant      2
# 68  41.058035  29.035684    710  avg avg  restaurant      2
# 77  41.073497  29.020494    504  avg avg     Italian      2

# %% [markdown]
# ### Shows below Average Rated venues

# %%
venues_data.loc[venues_data['label']==3]
# Out:
#                     name                        id          categories  \
# 0                   İoki  50377a92e4b0fc42f6c6bb79    Sushi Restaurant
# 31  Arnavutköy Balıkçısı  4c52f7547f6e20a1aae966ec  Seafood Restaurant
# 37    Nusr-Et Steakhouse  4fcf83e8e4b0d44b55e64acc          Steakhouse
# 46         Uskumru Balık  4b6dbc38f964a520da8a2ce3  Seafood Restaurant
# 49    Sunset Grill & Bar  4b66b8dff964a520a7282be3          Restaurant
# 51   Lacivert Restaurant  4c753eb13adda14327b606af  Seafood Restaurant
#
#           lat        lng  Likes Like Cat        type  label
# 0   41.073893  29.057801    822    great  restaurant      3
# 31  41.066640  29.042166   1671    great  restaurant      3
# 37  41.080561  29.033429   9130    great  restaurant      3
# 46  41.091037  29.066344   1332    great  restaurant      3
# 49  41.064121  29.033130   3200    great  restaurant      3
# 51  41.091380  29.066438   2918    great  restaurant      3

# %% [markdown]
# # Discussion :
#
#  From the above results we can state that the grouping of cuisines based on their rating is done very accurately but the results may have a limitation of accuracy as the whole results are based on the data we fetch from the Foursquare API calls hence further more advancements can be made by considering huge amounts of data.

# %% [markdown]
# # Conclusion :
#
#
# In this project, we tried to categorize the venues in Istanbul according to the numberof like  and type.We can say that we have achieved a successful result even though the FourSquare data is very low for Istanbul. Alsowe can say it is very useful For tourists who want to travel around the city and discover new quality venues. Therefor this work colud be  very useful for some company that creating advice programs and applications for tourist
